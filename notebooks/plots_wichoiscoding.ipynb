# %%
# %matplotlib inline
import matplotlib

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('../raw_data/data911.csv')

# %%
data = data[(data['codigo_cierre'] == 'D') == False]

# %%
data.describe()
# Out:
#        hora_creacion   hora_cierre       latitud      longitud    fin_semana  \
# count   1.224575e+06  1.224575e+06  1.224575e+06  1.224575e+06  1.224575e+06
# mean    1.448408e+01  1.424013e+01  1.938328e+01 -9.913600e+01  1.275806e-01
# std     6.085008e+00  6.712471e+00  7.604501e-02  2.280109e-01  3.336224e-01
# min     0.000000e+00  0.000000e+00  0.000000e+00 -9.937056e+01  0.000000e+00
# 25%     1.024722e+01  9.866667e+00  1.933620e+01 -9.917818e+01  0.000000e+00
# 50%     1.538000e+01  1.551306e+01  1.938456e+01 -9.913951e+01  0.000000e+00
# 75%     1.946417e+01  1.988861e+01  1.943466e+01 -9.909558e+01  0.000000e+00
# max     2.399972e+01  2.399972e+01  1.963220e+01  0.000000e+00  1.000000e+00
#
#           hora_pico  ids_clasificacion   dia_festivo
# count  1.224575e+06       1.224575e+06  1.224575e+06
# mean   1.570667e-01       8.475619e-01  1.343160e-02
# std    3.638638e-01       3.646500e-02  1.151139e-01
# min    0.000000e+00       7.582000e-01  0.000000e+00
# ...

# %%
sns.kdeplot(data['hora_creacion'])
# Out:
# <Axes: xlabel='hora_creacion', ylabel='Density'>

# %%
sns.countplot(x='dia_semana', data=data, palette='viridis')
# Out:
# /tmp/ipykernel_13233/2614109377.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='dia_semana', data=data, palette='viridis')
# <Axes: xlabel='dia_semana', ylabel='count'>

# %%
sns.countplot(x='alcaldia_inicio', data=data, hue='codigo_cierre')
plt.xticks(rotation=90) 
plt.tight_layout()

# %%
codigo_cierre_df = pd.DataFrame(data.groupby(['alcaldia_inicio'])['codigo_cierre'].value_counts())

# %%
pd.set_option('display.max_rows', len(codigo_cierre_df))
codigo_cierre_df
# Out:
#                                        count
# alcaldia_inicio        codigo_cierre
# ALVARO OBREGON         D               55208
#                        A               55051
#                        N               22602
#                        F                8718
#                        I                 264
# AZCAPOTZALCO           A               37786
#                        D               34387
#                        N                9833
#                        F                3576
#                        I                 166
# BENITO JUAREZ          A               65593
#                        D               54681
#                        N               18151
#                        F                6941
#                        I                 272
# COYOACAN               A               62279
#                        D               58149
#                        N               23923
#                        F                7594
# ...

# %%
data.groupby(['fecha_creacion'])

# %%
data.columns
# Out:
# Index(['folio', 'fecha_creacion', 'hora_creacion', 'dia_semana',
#        'fecha_cierre', 'hora_cierre', 'tipo_incidente_c4', 'incidente_c4',
#        'alcaldia_inicio', 'latitud', 'longitud', 'codigo_cierre',
#        'clas_con_f_alarma', 'tipo_entrada', 'alcaldia_cierre', 'colonia',
#        'fin_semana', 'hora_pico', 'ids_clasificacion', 'dia_festivo'],
#       dtype='object')

# %%
sns.countplot(x='incidente_c4', data=data, palette='viridis', order='')
plt.xticks(rotation=90) 
plt.tight_layout()
# Out:
# /tmp/ipykernel_13233/4226582179.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='incidente_c4', data=data, palette='viridis')

# %%
string = 'Hola'

# %%
string.replace('H', 'h')
# Out:
# 'hola'
